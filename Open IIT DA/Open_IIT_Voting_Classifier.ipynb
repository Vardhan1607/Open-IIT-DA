# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
from sklearn.model_selection import (train_test_split,cross_val_predict,
                                     cross_val_score,cross_validate,GridSearchCV,StratifiedKFold
                                    )
from sklearn import ensemble, linear_model,svm,neighbors,neural_network
from sklearn.metrics import (classification_report,confusion_matrix,
                             accuracy_score,auc,mean_absolute_error,r2_score,mean_squared_error,
                             plot_roc_curve,roc_auc_score,roc_curve)
from sklearn.preprocessing import (OneHotEncoder,LabelEncoder,MinMaxScaler,StandardScaler,)
from sklearn.decomposition import PCA,kernel_pca,KernelPCA
from sklearn.feature_selection import SelectKBest, chi2
from xgboost import XGBClassifier,XGBRegressor
import lightgbm as lgb
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.decomposition.kernel_pca module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.decomposition. Anything that cannot be imported from sklearn.decomposition is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
df=pd.read_csv("Train_data.csv")
df.head()
# Out:
#       id  acousticness  danceability  ...  year duration-min  popularity
# 0   2015         0.949         0.235  ...  1947          3.0    very low
# 1  15901         0.855         0.456  ...  2020          2.4         low
# 2   9002         0.827         0.495  ...  1950          2.6    very low
# 3   6734         0.654         0.643  ...  1974          2.4         low
# 4  15563         0.738         0.705  ...  1973          3.4     average
#
# [5 rows x 17 columns]

# %%
def preprocessing(df, istest=False,isOutlier_removal=True):
    df=df.replace({"explicit":{"Yes":1,"No":0},
              "mode":{"Major":1,"Minor":0},})
    if not istest:
        df.popularity=df.popularity.replace({'very low': 1, 'low': 2, 'average': 3, 'high':4, 'very high': 5})
    
    release_date=pd.to_datetime(df.release_date)
    df=df.drop(columns=["id","release_date"])
    
    if isOutlier_removal:
        df.tempo[df.tempo==0]=39.875
        df["duration-min"]=df["duration-min"].clip(upper=10)
    return df,release_date
        
    
def feature_engineering(df,isdrop=True):
    df["day"]=release_date.dt.day
    
    #you may onhot encode the this feature
    df["day_of_week"]=release_date.dt.dayofweek
    
    df["day_of_year"]=release_date.dt.dayofyear
    df["month"]=release_date.dt.month
  
        
#     You may not drop key use it as a onehotencoder on it
    if isdrop:
        df=drop_feature(df,["month","key"])
    return df

# %%
# Plot distribution of a features for each class
def distWithPopularity(f,p):
    for val in p.unique():
        sns.distplot(f[p==val],label=str(val))
    plt.legend(list(map(str,p.unique())))
    plt.show()
    
def add_feature(x,f):
    return pd.concat([x,f],axis=1)

def drop_feature(x,cols):
    return x.drop(columns=cols,axis=1)

def get_revenue(y_true,y_pred):
    bid2revenue={1:2,2:4,3:6,4:8,5:10}
    r1_l=[bid2revenue[bid] for bid in y_true[y_pred==y_true]]
    r1=sum(r1_l)
    r2_l=[bid2revenue[a] if b>a else 0 for a,b in zip(list(y_true[y_pred!=y_true]),list(y_pred[y_pred!=y_true]))]
    r2=sum(r2_l)
    return r1+r2

def model_classifier(rmf,x,y,isval=False):
    if not isval:
        rmf.fit(x,y)
    y_pred=rmf.predict(x)
    if isval:
        print("\nValidation:")
    else:
        print("\nTrain:")
    print(classification_report(y,y_pred,digits=4))
    print()
    print(confusion_matrix(y,y_pred))
    print("-"*50)
    return rmf

def model_regressor(rmf,x,y,isval=False):
    if not isval:
        rmf.fit(x,y)
    y_pred=rmf.predict(x)
    if isval:
        print("\nValidation:")
    else:
        print("\nTrain:")
    print("R2 score: ",r2_score(y,y_pred))
    print("mae error: ",mean_absolute_error(y,y_pred))
    print("-"*50)
    return rmf,y_pred

# %%
df,release_date=preprocessing(df)
df=feature_engineering(df)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df
# Out:
#        acousticness  danceability  energy  ...  day  day_of_week  day_of_year
# 0            0.9490        0.2350  0.0276  ...    1            2            1
# 1            0.8550        0.4560  0.4850  ...   13            4          318
# 2            0.8270        0.4950  0.4990  ...    1            6            1
# 3            0.6540        0.6430  0.4690  ...   30            1          120
# 4            0.7380        0.7050  0.3110  ...    1            0            1
# ...             ...           ...     ...  ...  ...          ...          ...
# 12222        0.0408        0.8090  0.8010  ...    7            1            7
# 12223        0.9120        0.4510  0.2400  ...    1            3            1
# 12224        0.3280        0.5510  0.5640  ...    1            6            1
# 12225        0.1220        0.0608  0.9390  ...    1            4          244
# 12226        0.0380        0.3890  0.7680  ...   24            4          206
#
# [12227 rows x 17 columns]

# %%
X=df.drop(columns=["popularity","day_of_week"])
y=df.popularity
x_train,x_test,y_train,y_test=train_test_split(X,y,stratify=y,shuffle=True,test_size=0.2, random_state = 123)


#feature scaling to 0-1 
scaler=MinMaxScaler()
col=['day','loudness','tempo', 'year','duration-min', 'day_of_year']
x_train[col]=scaler.fit_transform(x_train[col])
x_test[col]=scaler.transform(x_test[col])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
def model(rmf,x,y,isval=False):
    if not isval:
        rmf.fit(x,y)
    y_pred=rmf.predict(x)
    if isval:
        print("\nValidation:")
    else:
        print("\nTrain:")
    print(classification_report(y,y_pred))
    print()
    print(confusion_matrix(y,y_pred))
    print("-"*50)
    return rmf

# %%
from sklearn.svm import SVC 
from sklearn.model_selection import GridSearchCV
parameters = {'C': [10, 100],  
              'gamma': [1, 0.1, 0.01, 0.001], 
              'kernel': ['rbf']}

# %%
cv=StratifiedKFold(shuffle=True,random_state=0)

# %%
grid_search = GridSearchCV(estimator = SVC(),
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10,
                           refit= True,
                           verbose=3)

# %%
grid_search.fit(x_train, y_train)
# Out:
# Fitting 10 folds for each of 50 candidates, totalling 500 fits
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.434, total=   6.8s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.8s remaining:    0.0s
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.479, total=   7.0s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   13.8s remaining:    0.0s
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.497, total=   7.0s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.455, total=   6.8s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.487, total=   6.7s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.453, total=   6.7s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.469, total=   6.8s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.431, total=   6.9s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.470, total=   6.8s
# [CV] C=0.1, class_weight=balanced, gamma=1, kernel=rbf ...............
# [CV]  C=0.1, class_weight=balanced, gamma=1, kernel=rbf, score=0.482, total=   6.9s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.410, total=   7.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.444, total=   7.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.470, total=   7.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.426, total=   7.2s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.435, total=   7.2s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.417, total=   7.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.458, total=   7.2s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.416, total=   7.2s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.453, total=   7.1s
# [CV] C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.447, total=   7.2s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.353, total=   8.8s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.378, total=   8.9s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.390, total=   9.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.359, total=   8.9s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.387, total=   8.9s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.358, total=   8.9s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.402, total=   9.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.363, total=   9.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.390, total=   9.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.374, total=   9.0s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.219, total=   9.6s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.255, total=   9.5s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.263, total=   9.5s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.263, total=   9.5s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.263, total=   9.4s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.213, total=   9.4s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.220, total=   9.4s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.256, total=   9.5s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.227, total=   9.5s
# [CV] C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.213, total=   9.8s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.238, total=   9.5s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.255, total=   9.5s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.263, total=   9.5s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.263, total=   9.5s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.263, total=   9.5s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.213, total=   9.6s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.255, total=   9.6s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.255, total=   9.5s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.255, total=   9.6s
# [CV] C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.255, total=   9.5s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.467, total=   6.3s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.490, total=   6.4s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.515, total=   6.6s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.482, total=   6.3s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.518, total=   6.3s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.467, total=   6.2s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.514, total=   6.5s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.470, total=   6.8s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.482, total=   7.0s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.504, total=   6.6s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.429, total=   6.4s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.475, total=   6.3s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.506, total=   6.3s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.456, total=   6.3s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.485, total=   6.3s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.444, total=   6.3s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.502, total=   6.2s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.454, total=   6.2s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.470, total=   6.3s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.481, total=   6.3s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.401, total=   7.6s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.416, total=   7.6s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.405, total=   7.6s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.425, total=   7.6s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.427, total=   7.6s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.418, total=   7.6s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.425, total=   7.6s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.402, total=   7.6s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.407, total=   7.6s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.407, total=   7.6s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.264, total=   7.9s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.264, total=   7.8s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.263, total=   7.9s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.263, total=   7.9s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.263, total=   7.9s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.264, total=   7.9s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.264, total=   7.9s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.264, total=   7.9s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.264, total=   8.0s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.264, total=   7.9s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.264, total=   7.9s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.264, total=   7.8s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.263, total=   7.9s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.263, total=   7.9s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.263, total=   7.8s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.264, total=   7.8s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.264, total=   7.9s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.264, total=   7.9s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.264, total=   7.8s
# [CV] C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=0.1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.264, total=   7.8s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.535, total=   5.5s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.547, total=   5.6s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.563, total=   5.6s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.513, total=   5.6s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.545, total=   5.6s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.532, total=   5.6s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.555, total=   5.6s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.529, total=   5.6s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.512, total=   5.6s
# [CV] C=1, class_weight=balanced, gamma=1, kernel=rbf .................
# [CV]  C=1, class_weight=balanced, gamma=1, kernel=rbf, score=0.524, total=   5.6s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.477, total=   5.9s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.517, total=   5.8s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.518, total=   5.9s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.487, total=   5.9s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.512, total=   5.9s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.492, total=   5.9s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.511, total=   6.0s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.502, total=   5.9s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.507, total=   5.9s
# [CV] C=1, class_weight=balanced, gamma=0.1, kernel=rbf ...............
# [CV]  C=1, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.497, total=   5.9s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.429, total=   7.0s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.448, total=   7.1s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.466, total=   7.1s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.422, total=   7.0s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.439, total=   7.0s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.426, total=   7.0s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.444, total=   7.0s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.431, total=   7.0s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.450, total=   7.0s
# [CV] C=1, class_weight=balanced, gamma=0.01, kernel=rbf ..............
# [CV]  C=1, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.436, total=   7.0s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.352, total=   8.9s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.387, total=   8.9s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.390, total=   8.9s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.376, total=   8.8s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.383, total=   8.8s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.358, total=   8.8s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.404, total=   8.8s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.369, total=   8.9s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.389, total=   8.9s
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.381, total=   8.9s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.153, total=   9.5s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.227, total=   9.5s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.219, total=   9.4s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.234, total=   9.5s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.216, total=   9.4s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.238, total=   9.4s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.255, total=   9.4s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.255, total=   9.5s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.255, total=   9.5s
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.255, total=   9.5s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.536, total=   5.2s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.562, total=   5.2s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.572, total=   5.2s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.531, total=   5.1s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.575, total=   5.2s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.548, total=   5.2s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.555, total=   5.2s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.543, total=   5.2s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.524, total=   5.2s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.533, total=   5.2s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.504, total=   5.1s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.539, total=   5.2s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.557, total=   5.2s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.507, total=   5.1s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.531, total=   5.2s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.513, total=   5.1s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.543, total=   5.1s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.528, total=   5.1s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.521, total=   5.1s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.525, total=   5.1s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.453, total=   6.0s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.500, total=   6.0s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.509, total=   6.0s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.471, total=   6.0s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.495, total=   6.0s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.473, total=   5.9s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.518, total=   6.0s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.465, total=   6.0s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.471, total=   6.0s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.496, total=   5.9s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.399, total=   7.4s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.418, total=   7.3s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.405, total=   7.4s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.427, total=   7.4s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.430, total=   7.4s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.419, total=   7.4s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.433, total=   7.4s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.411, total=   7.4s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.411, total=   7.5s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.407, total=   7.4s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.264, total=   7.8s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.264, total=   7.8s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.263, total=   7.7s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.263, total=   7.8s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.263, total=   7.7s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.264, total=   7.8s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.264, total=   7.8s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.264, total=   7.8s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.264, total=   7.8s
# [CV] C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=1, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.264, total=   7.8s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.530, total=   5.7s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.546, total=   5.8s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.560, total=   5.9s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.556, total=   5.8s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.584, total=   5.8s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.555, total=   5.9s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.563, total=   5.8s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.571, total=   5.8s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.543, total=   5.8s
# [CV] C=10, class_weight=balanced, gamma=1, kernel=rbf ................
# [CV]  C=10, class_weight=balanced, gamma=1, kernel=rbf, score=0.555, total=   5.8s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.522, total=   5.4s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.555, total=   5.4s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.549, total=   5.5s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.538, total=   5.4s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.546, total=   5.5s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.521, total=   5.5s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.540, total=   5.5s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.541, total=   5.4s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.529, total=   5.5s
# [CV] C=10, class_weight=balanced, gamma=0.1, kernel=rbf ..............
# [CV]  C=10, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.511, total=   5.4s
# [CV] C=10, class_weight=balanced, gamma=0.01, kernel=rbf .............
# [CV]  C=10, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.467, total=   6.0s
# [CV] C=10, class_weight=balanced, gamma=0.01, kernel=rbf .............
# [CV]  C=10, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.521, total=   6.0s
# [CV] C=10, class_weight=balanced, gamma=0.01, kernel=rbf .............
# [CV]  C=10, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.485, total=   5.8s
# [CV] C=10, class_weight=balanced, gamma=0.01, kernel=rbf .............
# [CV]  C=10, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.471, total=   5.9s
# [CV] C=10, class_weight=balanced, gamma=0.01, kernel=rbf .............
# [CV]  C=10, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.501, total=   6.0s
# [CV] C=10, class_weight=balanced, gamma=0.01, kernel=rbf .............
# [CV]  C=10, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.476, total=   5.9s
# [CV] C=10, class_weight=balanced, gamma=0.01, kernel=rbf .............
# [CV]  C=10, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.495, total=   5.9s
# [CV] C=10, class_weight=balanced, gamma=0.01, kernel=rbf .............
# [CV]  C=10, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.499, total=   6.0s
# [CV] C=10, class_weight=balanced, gamma=0.01, kernel=rbf .............
# [CV]  C=10, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.485, total=   5.9s
# [CV] C=10, class_weight=balanced, gamma=0.01, kernel=rbf .............
# [CV]  C=10, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.482, total=   5.9s
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.421, total=   7.0s
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.455, total=   7.0s
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.465, total=   6.9s
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.419, total=   6.9s
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.440, total=   6.9s
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.435, total=   7.0s
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.437, total=   7.0s
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.435, total=   7.0s
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.455, total=   7.0s
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.428, total=   7.0s
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.353, total=   8.9s
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.385, total=   8.9s
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.390, total=   8.9s
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.379, total=   8.9s
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.383, total=   8.9s
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.356, total=   9.0s
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.402, total=   8.9s
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.367, total=   8.9s
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.387, total=   8.9s
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.379, total=   8.8s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.542, total=   5.9s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.547, total=   5.9s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.552, total=   6.0s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.553, total=   5.9s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.581, total=   5.9s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.558, total=   5.9s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.560, total=   5.9s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.572, total=   5.9s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.550, total=   5.9s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.556, total=   5.9s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.549, total=   5.1s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.576, total=   5.1s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.575, total=   5.2s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.545, total=   5.1s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.564, total=   5.1s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.537, total=   5.2s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.571, total=   5.2s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.563, total=   5.1s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.544, total=   5.1s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.535, total=   5.2s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.486, total=   5.3s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.552, total=   5.3s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.518, total=   5.3s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.505, total=   5.3s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.526, total=   5.3s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.500, total=   5.3s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.528, total=   5.3s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.518, total=   5.3s
# [CV] C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=10, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.504, total=   5.3s
# ...
# [CV] C=100, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=100, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.550, total=   7.2s
# [CV] C=100, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=100, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.575, total=   7.3s
# [CV] C=100, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=100, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.581, total=   7.2s
# [CV] C=100, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=100, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.541, total=   7.2s
# [CV] C=100, class_weight=balanced, gamma=0.1, kernel=rbf .............
# [CV]  C=100, class_weight=balanced, gamma=0.1, kernel=rbf, score=0.552, total=   7.2s
# [CV] C=100, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=100, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.485, total=   6.0s
# [CV] C=100, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=100, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.540, total=   6.2s
# [CV] C=100, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=100, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.527, total=   6.2s
# [CV] C=100, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=100, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.502, total=   6.2s
# [CV] C=100, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=100, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.534, total=   6.2s
# [CV] C=100, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=100, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.508, total=   6.1s
# [CV] C=100, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=100, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.519, total=   6.1s
# [CV] C=100, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=100, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.507, total=   6.2s
# [CV] C=100, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=100, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.498, total=   6.0s
# [CV] C=100, class_weight=balanced, gamma=0.01, kernel=rbf ............
# [CV]  C=100, class_weight=balanced, gamma=0.01, kernel=rbf, score=0.495, total=   6.2s
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.455, total=   6.1s
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.510, total=   6.1s
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.480, total=   6.1s
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.457, total=   6.1s
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.497, total=   6.2s
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.469, total=   6.1s
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.493, total=   6.1s
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.487, total=   6.1s
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.473, total=   6.1s
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.476, total=   6.1s
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.420, total=   7.0s
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.450, total=   7.0s
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.466, total=   6.9s
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.420, total=   7.0s
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.441, total=   6.9s
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.442, total=   7.0s
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.443, total=   7.1s
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.429, total=   7.0s
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.451, total=   7.1s
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.427, total=   7.0s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.486, total=  10.3s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.503, total=   9.7s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.537, total=  10.1s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.535, total=  10.1s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.540, total=  10.2s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.517, total=  10.5s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.533, total=  10.3s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.529, total=  10.3s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.510, total=  10.1s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=1, kernel=rbf, score=0.506, total=  10.4s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.571, total=   7.4s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.595, total=   7.4s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.598, total=   7.6s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.552, total=   7.4s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.587, total=   7.4s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.562, total=   7.4s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.582, total=   7.4s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.586, total=   7.4s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.567, total=   7.3s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.1, kernel=rbf, score=0.569, total=   7.4s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.525, total=   5.8s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.558, total=   5.9s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.561, total=   5.9s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.534, total=   5.9s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.553, total=   5.9s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.526, total=   5.8s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.549, total=   5.8s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.546, total=   5.8s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.532, total=   5.8s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.01, kernel=rbf, score=0.516, total=   5.8s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.474, total=   5.4s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.534, total=   5.4s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.507, total=   5.5s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.482, total=   5.4s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.522, total=   5.4s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.488, total=   5.5s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.511, total=   5.5s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.512, total=   5.5s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.485, total=   5.5s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.001, kernel=rbf, score=0.498, total=   5.4s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.455, total=   6.2s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.491, total=   6.2s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.500, total=   6.1s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.458, total=   6.2s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.500, total=   6.1s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.485, total=   6.1s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.505, total=   6.1s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.457, total=   6.1s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.467, total=   6.2s
# [CV] C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf
# [CV]  C=100, class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, gamma=0.0001, kernel=rbf, score=0.503, total=   6.1s
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed: 57.9min finished
# GridSearchCV(cv=10, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [0.1, 1, 10, 50, 100],
#                          'class_weight': ['balanced',
#                                           {1: 1, 2: 1, 3: 1, 4: 1, 5: 5}],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=3)

# %%
print(grid_search .best_params_) 
  
# print how our model looks after hyper-parameter tuning 
print(grid_search .best_estimator_)
# Out:
# {'C': 100, 'class_weight': {1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, 'gamma': 0.1, 'kernel': 'rbf'}
# SVC(C=100, break_ties=False, cache_size=200,
#     class_weight={1: 1, 2: 1, 3: 1, 4: 1, 5: 5}, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
import warnings
svc=SVC(C=100,gamma=0.1,kernel='rbf')
rmf=model(svc,x_train,y_train)
rmf=model(svc,x_test,y_test,isval=True)
# Out:
# Train:
#               precision    recall  f1-score   support
#
#            1       0.87      0.78      0.82      2577
#            2       0.57      0.74      0.65      2494
#            3       0.54      0.49      0.52      2330
#            4       0.60      0.61      0.61      2085
#            5       0.00      0.00      0.00       295
#
#     accuracy                           0.64      9781
#    macro avg       0.52      0.53      0.52      9781
# weighted avg       0.63      0.64      0.63      9781
#
#
# [[2010  268   63  236    0]
#  [ 194 1848  423   29    0]
#  [  59  805 1140  326    0]
#  [  56  285  462 1282    0]
#  [   2   14    7  272    0]]
# --------------------------------------------------
#
# Validation:
#               precision    recall  f1-score   support
#
#            1       0.86      0.78      0.82       645
#            2       0.54      0.71      0.62       624
#            3       0.51      0.47      0.49       582
#            4       0.61      0.60      0.60       521
#            5       0.00      0.00      0.00        74
#
#     accuracy                           0.63      2446
#    macro avg       0.50      0.51      0.50      2446
# weighted avg       0.62      0.63      0.62      2446
#
#
# [[501  84  22  38   0]
#  [ 58 442 119   5   0]
#  [  9 206 276  91   0]
#  [ 12  77 122 310   0]
#  [  2   3   3  66   0]]
# --------------------------------------------------

# %%
y_pred=svc.predict(x_test)
get_revenue(y_test,y_pred)
# Out:
# 8236

# %%
param = {'C': [10, 100],  
              'gamma': [1, 0.1, 0.01, 0.001], 
              'kernel': ['rbf']}

# %%
from sklearn.svm import SVC 
from sklearn.ensemble import VotingClassifier 
estimator = [] 
estimator.append(('RMF', ensemble.RandomForestClassifier(n_estimators=500,min_samples_leaf=5,max_features="sqrt",n_jobs=-1)))
estimator.append(('SVC', SVC(C=100,kernel="rbf",gamma ='auto', probability = True))) 
estimator.append(('LGB',lgb.LGBMClassifier()))
estimator.append(('XGB',XGBClassifier(colsample_bylevel=0.8,colsample_bynode=1, colsample_bytree=0.8, gamma=0,learning_rate=0.005, max_depth=8,min_child_weight=1,n_estimators=1000, n_jobs=-1,objective='multi:softprob', reg_alpha=0,reg_lambda=1,  subsample=0.8)))

# %%
grid_search = GridSearchCV(estimator = SVC(),
                           param_grid = param,
                           scoring = 'accuracy',
                           cv = 10,
                           refit= True,
                           verbose=3)
grid_search.fit(x_train, y_train)
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.562, total=   5.9s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    5.9s remaining:    0.0s
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.562, total=   6.2s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   12.1s remaining:    0.0s
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.571, total=   6.2s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.573, total=   6.2s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.596, total=   6.6s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.566, total=   6.6s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.580, total=   6.6s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.589, total=   6.6s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.567, total=   6.2s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.570, total=   6.6s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.576, total=   5.5s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.610, total=   5.5s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.625, total=   5.6s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.578, total=   5.3s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.591, total=   5.1s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.576, total=   5.4s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.616, total=   5.4s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.599, total=   5.5s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.581, total=   5.6s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.578, total=   5.6s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.522, total=   5.5s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.590, total=   5.5s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.560, total=   5.7s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.536, total=   5.7s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.560, total=   5.5s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.539, total=   5.5s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.574, total=   5.2s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.555, total=   5.2s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.536, total=   5.2s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.549, total=   5.2s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.484, total=   5.9s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.525, total=   5.9s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.543, total=   5.9s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.488, total=   5.8s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.505, total=   5.8s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.513, total=   6.1s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.543, total=   6.4s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.497, total=   6.1s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.490, total=   5.7s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.530, total=   5.8s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.490, total=  10.3s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.507, total=  10.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.538, total=  10.4s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.533, total=  10.4s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.542, total=  10.4s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.517, total=  11.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.531, total=  10.5s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.527, total=  10.6s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.509, total=  10.7s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.504, total=  10.8s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.599, total=   7.3s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.620, total=   7.2s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.639, total=   7.4s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.595, total=   7.9s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.617, total=   8.0s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.584, total=   7.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.618, total=   7.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.611, total=   7.4s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.594, total=   7.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.594, total=   7.6s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.564, total=   6.3s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.602, total=   6.1s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.610, total=   6.3s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.572, total=   6.1s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.587, total=   6.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.565, total=   6.4s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.598, total=   6.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.586, total=   6.1s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.566, total=   6.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.564, total=   6.2s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.515, total=   5.4s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.577, total=   5.5s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.552, total=   5.6s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.522, total=   5.4s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.554, total=   5.4s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.522, total=   5.4s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.560, total=   5.5s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.551, total=   5.5s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.520, total=   5.5s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.542, total=   5.4s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:  8.8min finished
# GridSearchCV(cv=10, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [10, 100], 'gamma': [1, 0.1, 0.01, 0.001],
#                          'kernel': ['rbf']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='accuracy', verbose=3)

# %%
print(grid_search .best_params_) 
  
# print how our model looks after hyper-parameter tuning 
print(grid_search .best_estimator_)
# Out:
# {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# SVC(C=100, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
svc=SVC(C=1,gamma=0.1,kernel='rbf')
rmf=model(svc,x_train,y_train)
rmf=model(svc,x_test,y_test,isval=True)
# Out:
# Train:
#               precision    recall  f1-score   support
#
#            1       0.78      0.66      0.72      2577
#            2       0.55      0.64      0.59      2494
#            3       0.49      0.50      0.50      2330
#            4       0.52      0.58      0.55      2085
#            5       0.00      0.00      0.00       295
#
#     accuracy                           0.58      9781
#    macro avg       0.47      0.48      0.47      9781
# weighted avg       0.57      0.58      0.57      9781
#
#
# [[1706  288  147  436    0]
#  [ 355 1590  473   76    0]
#  [  91  730 1168  341    0]
#  [  34  264  576 1211    0]
#  [   3   11   23  258    0]]
# --------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Validation:
#               precision    recall  f1-score   support
#
#            1       0.77      0.66      0.71       645
#            2       0.53      0.62      0.57       624
#            3       0.47      0.47      0.47       582
#            4       0.51      0.57      0.54       521
#            5       0.00      0.00      0.00        74
#
#     accuracy                           0.57      2446
#    macro avg       0.46      0.46      0.46      2446
# weighted avg       0.56      0.57      0.56      2446
#
#
# [[424  93  29  99   0]
#  [100 390 118  16   0]
#  [ 19 192 275  96   0]
#  [  8  63 155 295   0]
#  [  0   2   4  68   0]]
# --------------------------------------------------
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
rmf=model(vote,x_test,y_test,isval=True)
# Out:
# Validation:
#               precision    recall  f1-score   support
#
#            1       0.82      0.83      0.83       645
#            2       0.55      0.71      0.62       624
#            3       0.52      0.47      0.49       582
#            4       0.65      0.57      0.61       521
#            5       0.75      0.12      0.21        74
#
#     accuracy                           0.64      2446
#    macro avg       0.66      0.54      0.55      2446
# weighted avg       0.64      0.64      0.63      2446
#
#
# [[537  52  21  35   0]
#  [ 77 443 102   2   0]
#  [ 20 222 274  66   0]
#  [ 15  80 127 296   3]
#  [  2   3   3  57   9]]
# --------------------------------------------------

# %%
y_pred = rmf.predict(x_test)

# %%
y_pred
# Out:
# array([4, 2, 1, ..., 3, 1, 3], dtype=int64)

# %%
get_revenue(y_test, y_pred)
# Out:
# 10910
